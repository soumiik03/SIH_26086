# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayak-coder/SIH_26086/blob/main/terai_teesta_zone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier

# %%
df=pd.read_csv('/content/terai_teesta_zone_2020_2025.csv')
df.head()
# Out:
#          Date               Zone    District  Latitude  Longitude  \
# 0  2020-01-01  Terai_Teesta_Zone  Jalpaiguri     26.54      88.72
# 1  2020-01-02  Terai_Teesta_Zone  Jalpaiguri     26.54      88.72
# 2  2020-01-03  Terai_Teesta_Zone  Jalpaiguri     26.54      88.72
# 3  2020-01-04  Terai_Teesta_Zone  Jalpaiguri     26.54      88.72
# 4  2020-01-05  Terai_Teesta_Zone  Jalpaiguri     26.54      88.72
#
#    Rainfall_Observed_mm  Tmax_C  Tmin_C  Relative_Humidity_pct  \
# 0                   0.0   20.19   12.17                   45.2
# 1                   0.0   21.51    9.77                   43.0
# 2                   0.0   21.51   11.13                   41.6
# 3                   0.0   22.89    9.57                   43.8
# 4                   0.0   21.09    9.79                   47.2
#
#    Solar_Radiation_MJm2  MJO_Phase  MJO_Amplitude  Nino34_Anomaly  \
# 0                 23.90          3          0.802          -0.912
# ...

# %%
df.shape
# Out:
# (8768, 18)

# %%
df = df.drop(['Zone','Date','Waterlogging_Risk_Index'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8768 entries, 0 to 8767
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   District                 8768 non-null   object
#  1   Latitude                 8768 non-null   float64
#  2   Longitude                8768 non-null   float64
#  3   Rainfall_Observed_mm     8768 non-null   float64
#  4   Tmax_C                   8768 non-null   float64
#  5   Tmin_C                   8768 non-null   float64
#  6   Relative_Humidity_pct    8768 non-null   float64
#  7   Solar_Radiation_MJm2     8768 non-null   float64
#  8   MJO_Phase                8768 non-null   int64
#  9   MJO_Amplitude            8768 non-null   float64
#  10  Nino34_Anomaly           8768 non-null   float64
#  11  Dry_Spell_Days_Streak    8768 non-null   int64
#  12  Target_Crops             8768 non-null   object
#  13  Rolling_Rainfall_7d_mm   8768 non-null   float64
# ...

# %%
print(df['District'].unique())
print(df['Target_Crops'].unique())
# Out:
# ['Jalpaiguri' 'Alipurduar' 'Cooch_Behar' 'Siliguri_Foothill']
# ['Pineapple' 'Tea' 'Wetland_Rice']

# %%
le=LabelEncoder()
df['District']=le.fit_transform(df['District'])
df['Target_Crops']=df['Target_Crops'].map({'Pineapple':0,'Tea':1,'Wetland_Rice':2})
print(df['District'].unique())
print(df['Target_Crops'].unique())
# Out:
# [2 0 1 3]
# [0 1 2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8768 entries, 0 to 8767
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   District                 8768 non-null   int64
#  1   Latitude                 8768 non-null   float64
#  2   Longitude                8768 non-null   float64
#  3   Rainfall_Observed_mm     8768 non-null   float64
#  4   Tmax_C                   8768 non-null   float64
#  5   Tmin_C                   8768 non-null   float64
#  6   Relative_Humidity_pct    8768 non-null   float64
#  7   Solar_Radiation_MJm2     8768 non-null   float64
#  8   MJO_Phase                8768 non-null   int64
#  9   MJO_Amplitude            8768 non-null   float64
#  10  Nino34_Anomaly           8768 non-null   float64
#  11  Dry_Spell_Days_Streak    8768 non-null   int64
#  12  Target_Crops             8768 non-null   int64
#  13  Rolling_Rainfall_7d_mm   8768 non-null   float64
# ...

# %%
X=df.drop('Target_Crops',axis=1)
y=df['Target_Crops']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %%
rfc_model=RandomForestClassifier()
rfc_model.fit(X_train,y_train)
y_pred=rfc_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9942987457240593
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1084
#            1       0.99      0.98      0.98       289
#            2       0.98      0.99      0.99       381
#
#     accuracy                           0.99      1754
#    macro avg       0.99      0.99      0.99      1754
# weighted avg       0.99      0.99      0.99      1754

# %%
xgb_model=XGBClassifier()
xgb_model.fit(X_train,y_train)
y_pred=xgb_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9977194982896237
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1084
#            1       0.99      0.99      0.99       289
#            2       0.99      0.99      0.99       381
#
#     accuracy                           1.00      1754
#    macro avg       1.00      1.00      1.00      1754
# weighted avg       1.00      1.00      1.00      1754
