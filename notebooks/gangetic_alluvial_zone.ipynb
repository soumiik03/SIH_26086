# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayak-coder/SIH_26086/blob/main/gangetic_alluvial_zone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier

# %%
df=pd.read_csv('/content/gangetic_alluvial_zone_2020_2025.csv')
df.head()
# Out:
#          Date                        Zone         District  Latitude  \
# 0  2020-01-01  Gangetic_New_Alluvial_Zone  Purba_Bardhaman     23.25
# 1  2020-01-02  Gangetic_New_Alluvial_Zone  Purba_Bardhaman     23.25
# 2  2020-01-03  Gangetic_New_Alluvial_Zone  Purba_Bardhaman     23.25
# 3  2020-01-04  Gangetic_New_Alluvial_Zone  Purba_Bardhaman     23.25
# 4  2020-01-05  Gangetic_New_Alluvial_Zone  Purba_Bardhaman     23.25
#
#    Longitude  Rainfall_Observed_mm  Tmax_C  Tmin_C  Relative_Humidity_pct  \
# 0      87.85                  0.00   26.54   11.70                   41.4
# 1      87.85                  0.00   22.27   11.67                   50.7
# 2      87.85                  0.00   25.32   13.29                   43.1
# 3      87.85                  0.00   23.00   11.50                   40.2
# 4      87.85                 10.54   24.76   13.06                   45.2
#
#    Solar_Radiation_MJm2  MJO_Phase  MJO_Amplitude  Nino34_Anomaly  \
# ...

# %%
df.shape
# Out:
# (8768, 18)

# %%
print(df['District'].unique())
print(df['Target_Crops'].unique())
# Out:
# ['Purba_Bardhaman' 'Hooghly' 'Nadia' 'Murshidabad']
# ['Potato' 'Jute' 'Aman_Rice']

# %%
df = df.drop(['Zone','Date','Active_Crop_Cycle'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8768 entries, 0 to 8767
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   District                 8768 non-null   object
#  1   Latitude                 8768 non-null   float64
#  2   Longitude                8768 non-null   float64
#  3   Rainfall_Observed_mm     8768 non-null   float64
#  4   Tmax_C                   8768 non-null   float64
#  5   Tmin_C                   8768 non-null   float64
#  6   Relative_Humidity_pct    8768 non-null   float64
#  7   Solar_Radiation_MJm2     8768 non-null   float64
#  8   MJO_Phase                8768 non-null   int64
#  9   MJO_Amplitude            8768 non-null   float64
#  10  Nino34_Anomaly           8768 non-null   float64
#  11  Dry_Spell_Days_Streak    8768 non-null   int64
#  12  Target_Crops             8768 non-null   object
#  13  Rolling_Rainfall_7d_mm   8768 non-null   float64
# ...

# %%
le=LabelEncoder()
df['District']=le.fit_transform(df['District'])
df['Target_Crops']=df['Target_Crops'].map({'Potato':0,'Jute':1,'Aman_Rice':2})
print(df['District'].unique())
print(df['Target_Crops'].unique())
# Out:
# [3 0 2 1]
# [0 1 2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8768 entries, 0 to 8767
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   District                 8768 non-null   int64
#  1   Latitude                 8768 non-null   float64
#  2   Longitude                8768 non-null   float64
#  3   Rainfall_Observed_mm     8768 non-null   float64
#  4   Tmax_C                   8768 non-null   float64
#  5   Tmin_C                   8768 non-null   float64
#  6   Relative_Humidity_pct    8768 non-null   float64
#  7   Solar_Radiation_MJm2     8768 non-null   float64
#  8   MJO_Phase                8768 non-null   int64
#  9   MJO_Amplitude            8768 non-null   float64
#  10  Nino34_Anomaly           8768 non-null   float64
#  11  Dry_Spell_Days_Streak    8768 non-null   int64
#  12  Target_Crops             8768 non-null   int64
#  13  Rolling_Rainfall_7d_mm   8768 non-null   float64
# ...

# %%
X=df.drop('Target_Crops',axis=1)
y=df['Target_Crops']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %%
rfc_model=RandomForestClassifier()
rfc_model.fit(X_train,y_train)
y_pred=rfc_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9332953249714937
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       594
#            1       0.94      0.88      0.91       585
#            2       0.94      0.95      0.95       575
#
#     accuracy                           0.93      1754
#    macro avg       0.93      0.93      0.93      1754
# weighted avg       0.93      0.93      0.93      1754

# %%
xgb_model=XGBClassifier()
xgb_model.fit(X_train,y_train)
y_pred=xgb_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9589509692132269
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       594
#            1       0.96      0.95      0.95       585
#            2       0.96      0.97      0.96       575
#
#     accuracy                           0.96      1754
#    macro avg       0.96      0.96      0.96      1754
# weighted avg       0.96      0.96      0.96      1754
